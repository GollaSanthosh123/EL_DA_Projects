# %% [markdown]
# ## import the required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### import cleaned data using pandas

# %%
data=pd.read_excel("sharktankstartup.xlsx")
df=pd.DataFrame(data)
df
# Out:
#      Startup Name  Industry Founder Background Funding Stage  \
# 0       Startup 1   Fashion           Engineer      Series A
# 1       Startup 2   Fashion             Doctor          Seed
# 2       Startup 3   FinTech             Doctor        Growth
# 3       Startup 4    Travel           Engineer          Seed
# 4       Startup 5   FinTech           Designer      Series B
# ..            ...       ...                ...           ...
# 995   Startup 996    Health           Designer        Growth
# 996   Startup 997  AgriTech             Doctor        Growth
# 997   Startup 998  AgriTech    College Dropout          Seed
# 998   Startup 999      Food           Marketer     Prototype
# 999  Startup 1000   Fashion          Scientist        Growth
#
#      Investment Amount (INR Cr)  Equity Offered (%)  Deal Status Investor(s).1
# 0                          0.34               24.45     Accepted    Investor B
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ','')
df.rename(columns={'investor(s).1':'investors'},inplace=True)
df.head()
# Out:
#   startupname industry founderbackground fundingstage  \
# 0   Startup 1  Fashion          Engineer     Series A
# 1   Startup 2  Fashion            Doctor         Seed
# 2   Startup 3  FinTech            Doctor       Growth
# 3   Startup 4   Travel          Engineer         Seed
# 4   Startup 5  FinTech          Designer     Series B
#
#    investmentamount(inrcr)  equityoffered(%) dealstatus   investors
# 0                     0.34             24.45   Accepted  Investor B
# 1                     3.50             15.26   Rejected  Investor G
# 2                     1.89              1.37   Rejected  Investor G
# 3                     1.81              6.62   Accepted  Investor G
# 4                     6.33             27.63   Accepted  Investor C

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## *Column Chart*
# **Number Of Startups basedon founder background**

# %%
data=df.groupby('founderbackground')['startupname'].count().reset_index()
data.rename(columns={'startupname':'numberofstartups'},inplace=True)
plt.figure(figsize=(10,6))
plt.bar(data['founderbackground'],data['numberofstartups'],color='skyblue')
plt.title("Number Of Startups basedon founder background")
plt.xlabel("FounderBackground")
plt.ylabel("No.of.Startups")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## *Table Chart*
# **fund received based on funding stage**

# %%
data=df.groupby('fundingstage')['investmentamount(inrcr)'].sum().reset_index()
fig, ax = plt.subplots(figsize=(10, 2))
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=data.values, colLabels=data.columns, loc='center')
plt.title("Fund Received Based On Fundingstage")
plt.show()

# %% [markdown]
# ## *Pie Chart*
# **investment by industry**

# %%
data=df.groupby('industry')['investmentamount(inrcr)'].sum().reset_index()
plt.figure(figsize=(10,6))
plt.pie(x=data['investmentamount(inrcr)'],labels=data['industry'],autopct='%1.1f%%',labeldistance=1.2)
plt.title('Investment By Industry')
plt.show()

# %% [markdown]
# ## Average Investment By Investors

# %%
data=df.groupby('investors')['investmentamount(inrcr)'].mean().reset_index()
sns.barplot(x='investmentamount(inrcr)',y='investors',data=df,color='indigo')
plt.title("Average Investment By Investors")
plt.show()

# %% [markdown]
# ### Key Insights
# *College Dropout background peoples are started(137 startups) more starups than other*
# *seed funding stage is received more fund 903cr*
# *In Fashion Industry most of the people invested more 15% invested*
# *investor B is invested more than others*
